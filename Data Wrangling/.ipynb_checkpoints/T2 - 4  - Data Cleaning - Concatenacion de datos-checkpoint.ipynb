# %% [markdown]
# ## Concatenar y apendizar data sets
# * Concatenar datasets
#     > `whineData = pd.concat([redWine, whiteWine], axis = 0)`
# * Contar archivos de un directorio
#     >```[Python]
#     import os, os.path
#     DIR = '../../datasets/distributed-data/'
#     files = len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])
#     ```
# * Obtener elementos de una columna si repeticion
#     > `a = dataMain['Athlete'].unique().tolist()`
# * Unir dos tablas por una columna comun
#     > `dataFinal = pd.merge(left = dfQueIraALaIzquierda, right = dfQueIraALaDerecha,                    left_on='NombreDeColumnaIzquierda', right_on = 'NombreDeColumnaDerecha')`

# %%
import pandas as pd

# %%
redWine = pd.read_csv('../../datasets/wine/winequality-red.csv', sep = ';')
redWine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
redWine.columns.values
# Out:
# array(['fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'], dtype=object)

# %%
redWine.shape
# Out:
# (1599, 12)

# %%
whiteWine = pd.read_csv('../../datasets/wine/winequality-white.csv', sep = ';')
whiteWine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
whiteWine.shape
# Out:
# (4898, 12)

# %% [markdown]
# ###### En python tenemos dos tipos de ejes
# * axis = 0 -> eje horizontal
# * axis = 1 -> eje vertical

# %%
# Concatenamos los DataSets en el axis 0 

whineData = pd.concat([redWine, whiteWine], axis = 0)

# %%
whineData.shape
# Out:
# (6497, 12)

# %%
dw1 = whineData.head(10)
dw2 = whineData[300:310]
dw3 = whineData.tail(10)

# %%
# El resultado sera un dataset con los datos concatenados tal y como los hemos puesto

dw123 = pd.concat([dw1, dw2, dw3])
dw123
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 300             7.5             0.530         0.06            2.60      0.086
# ...

# %% [markdown]
# ## Datos distribuidos

# %%
data = pd.read_csv('../../datasets/distributed-data/001.csv')
data.head()
# Out:
#          Date  sulfate  nitrate  ID
# 0  2003-01-01      NaN      NaN   1
# 1  2003-01-02      NaN      NaN   1
# 2  2003-01-03      NaN      NaN   1
# 3  2003-01-04      NaN      NaN   1
# 4  2003-01-05      NaN      NaN   1

# %% [markdown]
# * Importar el primer fichero
# * Hacemos un bucle para recorrer todos los ficheros.
#     * Importante tener una consistencia en el nombre de los ficheros
#     * Importamos los ficheros uno a uno
#     * Cada uno debe apendizarse al primer fichero que habiamos cargado
# * Repetimos el bucle hasta que no queden ficheros

# %%
filePath  ='../../datasets/distributed-data/'

data = pd.read_csv('../../datasets/distributed-data/001.csv')

# Contar el numero de ficheros de un directorio
import os, os.path
DIR = '../../datasets/distributed-data/'
files = len([name for name in os.listdir(DIR) if os.path.isfile(os.path.join(DIR, name))])



for i in range(2,files + 1):
    if i < 10:
        fileName = '00' + str(i)
    elif 10 <= i < 100:
        fileName = '0' + str(i)
    else:
        fileName = str(i)
    
    fileName += '.csv'
    file = filePath + fileName
    
    tempData = pd.read_csv(file)

    
    
    data = pd.concat([data, tempData], axis = 0)
    
data
# Out:
#            Date  sulfate  nitrate   ID
# 0    2003-01-01      NaN      NaN    1
# 1    2003-01-02      NaN      NaN    1
# 2    2003-01-03      NaN      NaN    1
# 3    2003-01-04      NaN      NaN    1
# 4    2003-01-05      NaN      NaN    1
# 5    2003-01-06      NaN      NaN    1
# 6    2003-01-07      NaN      NaN    1
# 7    2003-01-08      NaN      NaN    1
# 8    2003-01-09      NaN      NaN    1
# 9    2003-01-10      NaN      NaN    1
# 10   2003-01-11      NaN      NaN    1
# 11   2003-01-12      NaN      NaN    1
# 12   2003-01-13      NaN      NaN    1
# 13   2003-01-14      NaN      NaN    1
# 14   2003-01-15      NaN      NaN    1
# 15   2003-01-16      NaN      NaN    1
# 16   2003-01-17      NaN      NaN    1
# 17   2003-01-18      NaN      NaN    1
# 18   2003-01-19      NaN      NaN    1
# 19   2003-01-20      NaN      NaN    1
# 20   2003-01-21      NaN      NaN    1
# 21   2003-01-22      NaN      NaN    1
# 22   2003-01-23      NaN      NaN    1
# ...

# %%
data = data.dropna(axis = 0, how='any')
data
# Out:
#             Date  sulfate  nitrate   ID
# 278   2003-10-06    7.210    0.651    1
# 284   2003-10-12    5.990    0.428    1
# 290   2003-10-18    4.680    1.040    1
# 296   2003-10-24    3.470    0.363    1
# 302   2003-10-30    2.420    0.507    1
# 314   2003-11-11    1.430    0.474    1
# 320   2003-11-17    2.760    0.425    1
# 326   2003-11-23    3.410    0.964    1
# 332   2003-11-29    1.300    0.491    1
# 338   2003-12-05    3.150    0.669    1
# 344   2003-12-11    2.870    0.400    1
# 356   2003-12-23    2.270    0.715    1
# 362   2003-12-29    2.330    0.554    1
# 368   2004-01-04    1.840    0.803    1
# 374   2004-01-10    7.130    0.518    1
# 386   2004-01-22    2.050    1.400    1
# 392   2004-01-28    2.050    0.979    1
# 398   2004-02-03    2.580    0.632    1
# 404   2004-02-09    3.260    0.506    1
# 416   2004-02-21    3.540    0.671    1
# 422   2004-02-27    4.400    0.602    1
# 428   2004-03-04    2.040    0.815    1
# ...

# %% [markdown]
# # Joins de Data Sets

# %%
filePath = '../../datasets/athletes/'

# %%
dataMain = pd.read_csv(filePath + 'Medals.csv', encoding = 'ISO-8859-1')

# %%
dataMain
# Out:
#                         Athlete   Age  Year Closing Ceremony Date  \
# 0                Michael Phelps  23.0  2008            08/24/2008
# 1                Michael Phelps  19.0  2004            08/29/2004
# 2                Michael Phelps  27.0  2012            08/12/2012
# 3              Natalie Coughlin  25.0  2008            08/24/2008
# 4                 Aleksey Nemov  24.0  2000            10/01/2000
# 5                 Alicia Coutts  24.0  2012            08/12/2012
# 6                Missy Franklin  17.0  2012            08/12/2012
# 7                   Ryan Lochte  27.0  2012            08/12/2012
# 8               Allison Schmitt  22.0  2012            08/12/2012
# 9              Natalie Coughlin  21.0  2004            08/29/2004
# 10                   Ian Thorpe  17.0  2000            10/01/2000
# 11                  Dara Torres  33.0  2000            10/01/2000
# 12                Cindy Klassen  26.0  2006            02/26/2006
# ...

# %%
# Obtenemos cuantos hay (sin repeticion)

a = dataMain['Athlete'].unique().tolist()

# %%
dataCountry = pd.read_csv(filePath + 'Athelete_Country_Map.csv', encoding = 'ISO-8859-1')

# %%
dataCountry[dataCountry['Athlete'] == 'Aleksandar Ciric']
# Out:
#                Athlete                Country
# 1029  Aleksandar Ciric                 Serbia
# 1086  Aleksandar Ciric  Serbia and Montenegro

# %%
dataSports = pd.read_csv(filePath + 'Athelete_Sports_Map.csv', encoding = 'ISO-8859-1')

# %%
dataSports.shape
# Out:
# (6975, 2)

# %%
dataSports[(dataSports['Athlete'] == 'Chen Jing') | 
           (dataSports['Athlete'] == 'Richard Thompson') | 
           (dataSports['Athlete'] == 'Matt Ryan')]
# Out:
#                Athlete         Sport
# 528   Richard Thompson     Athletics
# 1308         Chen Jing    Volleyball
# 1419         Chen Jing  Table Tennis
# 2727         Matt Ryan        Rowing
# 5003         Matt Ryan    Equestrian
# 5691  Richard Thompson      Baseball

# %% [markdown]
# #### Juntando tablas con merge

# %%
# Si no especificamos nada, hara un inner join como en SQL, combinando todos los datos

dataMainCountry = pd.merge(left = dataMain, right = dataCountry,
                          left_on = 'Athlete', right_on = 'Athlete')

# %%
# Como vemos los datos se han duplicado, anadiendo los dos paises a cada ano de los JJOO
dataMainCountry[dataMainCountry['Athlete'] == 'Aleksandar Ciric']
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1503  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1504  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1505  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1506  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1507  Aleksandar Ciric  22.0  2000            10/01/2000            0
# 1508  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals                Country
# 1503              0              1             1                 Serbia
# 1504              0              1             1  Serbia and Montenegro
# 1505              1              0             1                 Serbia
# 1506              1              0             1  Serbia and Montenegro
# 1507              0              1             1                 Serbia
# ...

# %%
# Para cada uno de los atletas, solo dejara un pais

dataCountryNoDuplicate = dataCountry.drop_duplicates(subset = 'Athlete')

type(dataCountryNoDuplicate)
# Out:
# pandas.core.frame.DataFrame

# %%
dataMainCountry = pd.merge(left = dataMain, right = dataCountryNoDuplicate,
                          left_on = 'Athlete', right_on = 'Athlete')

# Como vemos los datos ya no estan duplicados
dataMainCountry[dataMainCountry['Athlete'] == 'Aleksandar Ciric']
# Out:
#                Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 1491  Aleksandar Ciric  30.0  2008            08/24/2008            0
# 1492  Aleksandar Ciric  26.0  2004            08/29/2004            0
# 1493  Aleksandar Ciric  22.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals Country
# 1491              0              1             1  Serbia
# 1492              1              0             1  Serbia
# 1493              0              1             1  Serbia

# %%
dataSportsNoDuplicate = dataSports.drop_duplicates(subset = 'Athlete')

# %%
dataSportsNoDuplicate['Athlete'] == 'Michael Phelps'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 6945    False
# 6946    False
# 6947    False
# 6948    False
# 6949    False
# 6950    False
# 6951    False
# 6952    False
# 6953    False
# 6954    False
# 6955    False
# 6956    False
# 6957    False
# 6958    False
# 6959    False
# 6960    False
# 6961    False
# 6962    False
# 6963    False
# 6964    False
# 6965    False
# 6966    False
# 6967    False
# 6968    False
# 6969    False
# 6970    False
# 6971    False
# 6972    False
# 6973    False
# 6974    False
# ...

# %%
dataFinal = pd.merge(left = dataMainCountry, right = dataSportsNoDuplicate,
                    left_on='Athlete', right_on = 'Athlete')
dataFinal
# Out:
#                     Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0            Michael Phelps  23.0  2008            08/24/2008            8
# 1            Michael Phelps  19.0  2004            08/29/2004            6
# 2            Michael Phelps  27.0  2012            08/12/2012            4
# 3          Natalie Coughlin  25.0  2008            08/24/2008            1
# 4          Natalie Coughlin  21.0  2004            08/29/2004            2
# 5          Natalie Coughlin  29.0  2012            08/12/2012            0
# 6             Aleksey Nemov  24.0  2000            10/01/2000            2
# 7             Alicia Coutts  24.0  2012            08/12/2012            1
# 8            Missy Franklin  17.0  2012            08/12/2012            4
# 9               Ryan Lochte  27.0  2012            08/12/2012            2
# 10              Ryan Lochte  24.0  2008            08/24/2008            2
# ...

# %% [markdown]
# # Tipos de Joins

# %%
# Anadir o incrustar imagenes dentro del Notebook
from IPython.display import Image

# %% [markdown]
# ### Inner Join <= A(Left Join), B(Right Join) <= Outer Join

# %%
# Preparamos el DS para el ejemplo
import numpy as np

outAthletes = np.random.choice(dataMain['Athlete'], size = 6, replace = False)

# %%
dataCountryDlt = dataCountryNoDuplicate[(~dataCountryNoDuplicate['Athlete'].isin(outAthletes)) & (dataCountryNoDuplicate['Athlete'] != 'Michael Phelps')]

dataSportsDlt =   dataSportsNoDuplicate[(~dataSportsNoDuplicate['Athlete'].isin(outAthletes)) & (dataSportsNoDuplicate['Athlete'] != 'Michael Phelps')]

dataMainDlt = dataMain[(~dataMain['Athlete'].isin(outAthletes)) & (dataMain['Athlete'] != 'Michael Phelps')]

# %% [markdown]
# ## Inner Join

# %% [markdown]
# * Devuelve un dataframe con las filas que tienen valor tanto en el primero como en el segundo dataframe que estamos uniendo
# * El numero de filas sera igual al numero de filas **comunes** que tengan ambos datasets
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Inner Join B tendra 30 filas
# * En terminos de teoria de conjuntos, se trata de la Intercession de los dos conjuntos

# %%
Image(filename = '../../notebooks/resources/inner-join.png')

# %%
# DataMain contiene toda la informacion
# DataCountryDlt le falta la info de 7 atletas

mergedInner = pd.merge(left = dataMain, right = dataCountryDlt,
                      how = 'inner', left_on = 'Athlete', right_on = 'Athlete')

# %%
len(mergedInner)
# Out:
# 8604

# %% [markdown]
# ## Left Join

# %% [markdown]
# * Devuelve un DataFrame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del Data Frame final que no correspondan a ninguna fila del DF derecho, tindran NAs en las columnas del dataframe izquierdo.
# * El numero de filas sera igual al numero de filas del DF izquierdo
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Left Join B tendra 60 filas
# * En terminos de teoria de conjuntos, se trata del propio Data Set de la izquierda quien, ademas tiene la interseccion en su interior

# %%
Image(filename='../../notebooks/resources/left-join.png')

# %%
mergedLeft = pd.merge(left = dataMain, right = dataCountryDlt,
                     how = 'left', left_on = 'Athlete', right_on = 'Athlete')
len(mergedLeft)
# Out:
# 8618

# %%
mergedLeft.head()
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2    Michael Phelps  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
#
#    Silver Medals  Bronze Medals  Total Medals        Country
# 0              0              0             8            NaN
# 1              0              2             8            NaN
# 2              2              0             6            NaN
# 3              2              3             6  United States
# 4              1              3             6         Russia

# %% [markdown]
# ## Right Join

# %% [markdown]
# * Devuelve un DataFrame con las filas que tuvieran valor en el dataset de la izquierda, sin importar si tienen correspondencia en el de la derecha o no.
# * Las filas del Data Frame final que no correspondan a ninguna fila del DF izquierdo, tindran NAs en las columnas del dataframe derecho.
# * El numero de filas sera igual al numero de filas del DF derecho
#     * Data Set A tiene 60 filas
#     * Data Set B tiene 50 filas
#     * Entonces A Right Join B tendra 50 filas
# * En terminos de teoria de conjuntos, se trata del propio Data Set de la derecha quien, ademas tiene la interseccion en su interior

# %%
Image(filename='../../notebooks/resources/right-join.png')

# %%
mergedRight = pd.merge(left = dataMainDlt, right = dataCountryNoDuplicate, 
                       how = 'right', left_on = 'Athlete', right_on = 'Athlete')

# %%
mergedRight.tail(10)
# Out:
#                      Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 8601        Wietse van Alten  21.0  2000.0            10/01/2000          0.0
# 8602    Sandra Wagner-Sachse  31.0  2000.0            10/01/2000          0.0
# 8603               Rod White  23.0  2000.0            10/01/2000          0.0
# 8604          Michael Phelps   NaN     NaN                   NaN          NaN
# 8605             Ben Ainslie   NaN     NaN                   NaN          NaN
# 8606  Anna Mickelson-Cummins   NaN     NaN                   NaN          NaN
# 8607      Stephanie Schiller   NaN     NaN                   NaN          NaN
# 8608           Anna Glazkova   NaN     NaN                   NaN          NaN
# 8609             Dani Sruoga   NaN     NaN                   NaN          NaN
# 8610     Macha van der Vaart   NaN     NaN                   NaN          NaN
#
#       Silver Medals  Bronze Medals  Total Medals        Country
# ...

# %% [markdown]
# ## Outer Join

# %% [markdown]
# * Devuelve un DF con todas las filas de ambos, reemplazando las ausencias de un o de otro con NAs en la region especifica
# * Las filas del DF final que no corresponden a ninguna fila del DF derecho (o izquierdo), tendran Nas en las oclumnas del DF derecho ( o izquierdo )
# * El numero de filas sera igual al maximo numero de filas de ambos DF
#     * DS A tiene 60 filas
#     * DS Btiene 50 filas
#     * Ambos comparten 30 filas
#     * Entonces A Outer Join B tendra 60 + 50 - 30 = 80
# * En terminos de teoria de conjuntos, se trata de una union de conjuntos

# %%
Image(filename='../../notebooks/resources/outer-join.png')

# %%
dataCountryMg = dataCountryDlt.append(
    {
        'Athlete' : 'Marcos Gimenez Lopez',
        'Country' : 'Espana'
    }, ignore_index = True
)

# %%
mergedOuter = pd.merge(left = dataMain, right = dataCountryMg,
                      how = 'outer', left_on = 'Athlete', right_on = 'Athlete')
len(mergedOuter)
# Out:
# 8619
